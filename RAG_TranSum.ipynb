# %% [markdown]
# <a href="https://colab.research.google.com/github/prajeet26/RAG-TranSum/blob/main/RAG_TranSum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.8/276.8 kB 25.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 14.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.document_loaders import DirectoryLoader
from langchain.vectorstores.chroma import Chroma
from langchain.schema import Document
from typing import List
import warnings
import shutil
import os

# %%
warnings.filterwarnings("ignore")

# %%
os.environ['HUGGINGFACEHUB_API_TOKEN'] = "your_api_token"

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-9z90xrt0
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-9z90xrt0
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 33.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 40.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 45.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00
# ...

# %%
# !pip install argparse

# %%
# !pip install moviepy

# %%
import whisper
import argparse
import os

def transcribe_audio(audio_file_path):
    if not os.path.isfile(audio_file_path):
        print(f"Error: The file '{audio_file_path}' does not exist.")
        return

    try:
        model = whisper.load_model("base")
        transcription = model.transcribe(audio_file_path, fp16=False)

        def save_text_to_file():
            with open("transcribed_text.txt", 'w') as file:
                file.write(transcription['text'])

        save_text_to_file()
    except Exception as e:
        print(f"Error during transcription: {e}")

# Replace '/content/audio.mp3' with the path to your audio file
audio_file_path = '/content/drive/MyDrive/audio.mp3'
transcribe_audio(audio_file_path)
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 120MiB/s]

# %%
pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 1.9 MB/s eta 0:00:00
# ...

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 45.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 53.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders import TextLoader
from langchain.vectorstores.chroma import Chroma
from langchain.schema import Document
from typing import List
import warnings
import shutil
import os

warnings.filterwarnings("ignore")

os.environ['HUGGINGFACEHUB_API_TOKEN'] = "your_api_token"

CHROMA_PATH = "/content/chroma"
DATA_PATH = "/content/transcribed_text.txt"


def main():
    generate_data_store()

def generate_data_store():
    documents = load_documents()
    save_to_chroma(documents)

def load_documents():
    loader = TextLoader(DATA_PATH)
    documents = loader.load()
    return documents


def save_to_chroma(chunks: List[Document]):
    # Clear out the database first.
    if os.path.exists(CHROMA_PATH):
        shutil.rmtree(CHROMA_PATH)

    # Create a new DB from the documents.
    embedding_function = HuggingFaceEmbeddings()

    db = Chroma.from_documents(
        chunks, embedding_function, persist_directory=CHROMA_PATH
    )

    db.persist()

if __name__ == "__main__":
    main()
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.llms import HuggingFaceHub
from langchain.vectorstores.chroma import Chroma
from langchain.prompts import ChatPromptTemplate
import argparse
import warnings
import os


warnings.filterwarnings("ignore")

os.environ['HUGGINGFACEHUB_API_TOKEN'] = "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"
# os.environ['KMP_DUPLICATE_LIB_OK'] = "TRUE"

CHROMA_PATH = "/content/chroma"
PROMPT_TEMPLATE = """Given below the text: \n\n{context}\n\n Answer the question based on the above context: {question}\n"""

def main():

    embedding_function = HuggingFaceEmbeddings()
    db = Chroma(persist_directory=CHROMA_PATH, embedding_function=embedding_function)

    context = db.get()['documents']

    question = input("Would you like to condense or translate the text?\n")
    query = ""

    if question.lower() == "condense":

        query = "can you provide a brief summary of the text?"

        prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
        prompt = prompt_template.format(context=context, question=query)

        model = HuggingFaceHub(huggingfacehub_api_token=os.environ['HUGGINGFACEHUB_API_TOKEN'],
                                repo_id="mistralai/Mixtral-8x7B-Instruct-v0.1",
                                model_kwargs={"temperature":0.6, "max_new_tokens":200})

        response_text = model.predict(prompt)
        print(response_text)

    elif question.lower() == "translate":

        lang = input("Please enter the target language:\n")
        query = f"can you translate the text to {lang}?"

        prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
        prompt = prompt_template.format(context=context, question=query)

        model = HuggingFaceHub(huggingfacehub_api_token=os.environ['HUGGINGFACEHUB_API_TOKEN'],
                                repo_id="mistralai/Mixtral-8x7B-Instruct-v0.1",
                                model_kwargs={"temperature":0.6, "max_new_tokens":len(str(context))})

        response_text = model.predict(prompt)
        print(response_text)

    else:
        print("Please enter a valid option.")

if __name__ == "__main__":
    main()
# Out:
# Would you like to condense or translate the text?
# condense
# Human: Given below the text:
#
# [" CRED is the most overvalued Unicorn in India. Their valuation was $6.4 billion in FI-22 and their revenue last year was only $50 million. This gives them a revenue multiple of $121. And just for context, a startup is generally valued at around 1 to 2x to around 10x, depending on the sector and growth. Marketplaces, for example, are generally valued at 1 to 2x multiple of their revenue. Software companies, on the other hand, could be valued at 10x or more, if they are growing in the 3 digits. And CRED is at $121x, which is crazy. Another interesting thing to look at is the customer lifetime value. CRED has 16 million users. And if we divide it by its valuation, it gives us a CLV of $33,268 rupees, which means CRED has to make this much money from every single customer to justify its valuation. Let me know your opinion on CRED's valuation in the comments."]
#
# ...

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast
from langchain_community.llms import HuggingFaceHub
from langchain.vectorstores.chroma import Chroma
from langchain.prompts import ChatPromptTemplate
import argparse
import warnings
import os

warnings.filterwarnings("ignore")

os.environ['HUGGINGFACEHUB_API_TOKEN'] = "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"
CHROMA_PATH = "/content/chroma"
PROMPT_TEMPLATE = """Given below the text: \n\n{context}\n\n Answer the question based on the above context: {question}\n"""

def main():

    embedding_function = HuggingFaceEmbeddings()
    db = Chroma(persist_directory=CHROMA_PATH, embedding_function=embedding_function)

    context = db.get()['documents']

    question = input("Would you like to condense or translate the text?\n")
    query = ""

    if question.lower() == "condense":

        query = "can you provide a brief summary of the text?"

        prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
        prompt = prompt_template.format(context=context, question=query)

        model = HuggingFaceHub(huggingfacehub_api_token=os.environ['HUGGINGFACEHUB_API_TOKEN'],
                                repo_id="mistralai/Mixtral-8x7B-Instruct-v0.1",
                                model_kwargs={"temperature":0.6, "max_new_tokens":200})

        response_text = model.predict(prompt)
        print(response_text)

    elif question.lower() == "translate":
      lang = input("Please enter the target language:\n")
      query = f"can you translate the text to {lang}?"
      model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
      tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
      tokenizer.src_lang = "en_XX"

      encoded_context = tokenizer(context, return_tensors="pt")
      generated_tokens = model.generate(
          **encoded_context,
          forced_bos_token_id=tokenizer.lang_code_to_id[f"{lang}_XX"]
          )

      response_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
      print(response_text)


    else:
        print("Please enter a valid option.")

if __name__ == "__main__":
    main()
# Out:
# Would you like to condense or translate the text?
# translate
# Please enter the target language:
# ja
# ['CREDはインドで最も過高評価のユニコーンです. 彼らの評価はFI-22で6.4億ドルであり、昨年の収入はわずか50百万ドルでした. これは彼らに121の収入の倍数を与えます. そして、ちょうどコンテキストのために, スタートアップは一般的に1から2xに約10xで評価されます, セクターと成長に依存します. マーケットプレイス, 例えば, 一般的に1から2xの彼らの収入の倍数で評価されています. ソフトウェア会社, 一方, 彼らが3桁で成長している場合、10xまたはそれ以上で評価することができます. そして、CREDは121xであります, これは狂っています. 別の興味深いことに見てみましょう 顧客の生涯価値です. CREDは16百万のユーザーを持っています. そして、我々はその評価でそれを分割した場合, それは33,268ルーピーの']
